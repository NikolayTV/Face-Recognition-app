# %%
import plotly.express as px
import pandas as pd
from glob import glob


logDf = pd.read_csv(f'logs/tables/2020-06-28 15.csv')
    
fig = px.line(logDf, x='time', y='num_faces')
fig.show()
# Out:
# <div>
#
#
#             <div id="693a1fa3-ca0e-4894-986d-1c1d7f6f6bc6" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("693a1fa3-ca0e-4894-986d-1c1d7f6f6bc6")) {
#                     Plotly.newPlot(
#                         '693a1fa3-ca0e-4894-986d-1c1d7f6f6bc6',
# ...
